# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf

# Download minute-wise data
data = yf.download('AAPL',period='10m', interval='1m')

# Calculate moving averages
data['SMA_20'] = data['Close'].rolling(window=2).mean()
data['SMA_50'] = data['Close'].rolling(window=5).mean()

# Calculate Bollinger Bands
data['20_SMA'] = data['Close'].rolling(window=20).mean()
data['20_std'] = data['Close'].rolling(window=20).std()
data['Upper_Band'] = data['20_SMA'] + (data['20_std'] * 2)
data['Lower_Band'] = data['20_SMA'] - (data['20_std'] * 2)

# Plot candlestick chart with indicators
mpf.plot(data, type='candle', style='charles',
         volume=True,
         tight_layout=False, title='AAPL Candlestick Chart with SMA and Bollinger Bands')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-04-24 15:50:00-04:00  169.119995  169.300003  169.110001  169.279800
# 2024-04-24 15:51:00-04:00  169.270004  169.274994  169.050003  169.154999
# 2024-04-24 15:52:00-04:00  169.149994  169.156494  169.050003  169.100006
# 2024-04-24 15:53:00-04:00  169.104996  169.104996  169.000000  169.032394
# 2024-04-24 15:54:00-04:00  169.029999  169.089996  168.669998  168.741501
# 2024-04-24 15:55:00-04:00  168.750000  169.159897  168.744995  169.139893
# 2024-04-24 15:56:00-04:00  169.130005  169.250000  169.095001  169.125000
# 2024-04-24 15:57:00-04:00  169.125000  169.195007  169.070007  169.179993
# 2024-04-24 15:58:00-04:00  169.184998  169.197403  169.110001  169.125000
# 2024-04-24 15:59:00-04:00  169.125000  169.130005  168.949997  168.949997
#
#                             Adj Close  Volume      SMA_20      SMA_50  20_SMA  \
# Datetime
# ...
